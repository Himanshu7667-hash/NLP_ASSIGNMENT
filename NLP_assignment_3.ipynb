# %% [markdown]
# # Assignment 3: Sentiment Analysis with LSTM
# ---
# * **Name:** Himanshu kumar
# * **Roll No.:** 2301201167

# %%
# Import necessary libraries from TensorFlow/Keras
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# 1. Set up parameters and load the data
num_words = 10000  # Consider the top 10,000 most frequent words
maxlen = 200       # Set the length of each review to 200 words

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=num_words)

# 2. Preprocess the data: Pad sequences
X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)

print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of X_test: {X_test.shape}")
print("\n" + "="*30 + "\n")

# 3. Build the LSTM Model
model = Sequential([
    Embedding(num_words, 128, input_length=maxlen),
    LSTM(128, dropout=0.2, recurrent_dropout=0.2),
    Dense(1, activation='sigmoid')
])

# 4. Compile the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print("--- Model Summary ---")
model.summary()
print("\n" + "="*30 + "\n")

# 5. Train the model
print("--- Starting Model Training ---")
model.fit(X_train, y_train,
          epochs=3,
          batch_size=64,
          validation_data=(X_test, y_test))
print("\n" + "="*30 + "\n")

# 6. Evaluate the model
print("--- Evaluating Model Performance ---")
loss, acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Shape of X_train: (25000, 200)
# Shape of X_test: (25000, 200)
#
# ==============================
#
# --- Model Summary ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# ==============================
#
# --- Starting Model Training ---
# Epoch 1/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 185s 466ms/step - accuracy: 0.7044 - loss: 0.5472 - val_accuracy: 0.7921 - val_loss: 0.4589
# Epoch 2/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 188s 429ms/step - accuracy: 0.8369 - loss: 0.3812 - val_accuracy: 0.8446 - val_loss: 0.3658
# Epoch 3/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 184s 471ms/step - accuracy: 0.8806 - loss: 0.3013 - val_accuracy: 0.8512 - val_loss: 0.3604
#
# ==============================
#
# --- Evaluating Model Performance ---
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.8514 - loss: 0.3599
# Test Accuracy: 0.8512
